# %% [markdown]
# # CrossReference Harvard to CrossRef Data

# %% [markdown]
# ## Import statements

# %%
import pandas as pd
import json
import os
import glob
import logging
import sys
from datetime import datetime
from typing import List, Dict, Any, Set, Optional
from pathlib import Path

# %% [markdown]
# ## Set up global variables

# %%
LOGGING_FILE_NAME = "logs/harvard_crossref_match_"
HARVARD_MD_FILE = "Output Data/Harvard Data with LCC Subjects and only ISSN.xlsx"
CROSSREF_MD_DIR = "crossref_cache"
OUTPUT_MD_FILE_ROOT = "harvard_crossref_match_final"

# %% [markdown]
# ## Set up Logging

# %%
# Setup logging first
def setup_logging():
    """Configure logging with both file and console handlers with Unicode support."""
    # Create logs directory if it doesn't exist
    os.makedirs('logs', exist_ok=True)
    
    # Create formatters for different levels of detail
    brief_formatter = logging.Formatter('%(message)s')
    verbose_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    
    # Create and configure handlers
    log_filename = f"logs/harvard_crossref_match_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"
    
    # Clear any existing handlers
    logger = logging.getLogger()
    for handler in logger.handlers[:]:
        logger.removeHandler(handler)
    
    # File handler with UTF-8 encoding
    file_handler = logging.FileHandler(log_filename, encoding='utf-8')
    file_handler.setLevel(logging.DEBUG)
    file_handler.setFormatter(verbose_formatter)
    
    # Console handler with system encoding
    console_handler = logging.StreamHandler(sys.stdout)
    console_handler.setLevel(logging.INFO)
    console_handler.setFormatter(brief_formatter)
    
    # Configure root logger
    logger.setLevel(logging.DEBUG)
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    return logger

# %% [markdown]
# ## Set up for Processing

# %%
def create_checkpoint_dir():
    """Create directory for checkpoint files if it doesn't exist."""
    checkpoint_dir = Path("Harvard Analysis Checkpoints")
    checkpoint_dir.mkdir(exist_ok=True)
    return checkpoint_dir

# %% [markdown]
# ## Normalize the ISSN

# %%
def normalize_issn(issn: str) -> str:
    """
    Normalize ISSN to standard format (removes spaces, 'ISSN', and hyphens)
    Returns None if the ISSN doesn't look valid after normalization
    Valid ISSN format:
    - Must be 8 characters
    - First 7 characters must be digits
    - Last character can be a digit or 'X'
    """
    if not isinstance(issn, str):
        issn = str(issn)
    
    # Remove common prefixes, spaces, and hyphens
    issn = issn.upper().replace('ISSN', '').replace(' ', '').replace('-', '').strip()
    
    # Basic validation:
    # 1. Should be 8 characters after normalization
    if len(issn) != 8:
        return None
        
    # 2. First 7 characters must be digits
    if not issn[:7].isdigit():
        return None
        
    # 3. Last character must be a digit or 'X'
    if not (issn[-1].isdigit() or issn[-1] == 'X'):
        return None
        
    return issn

def validate_issn_list(issns: Set[str]) -> Set[str]:
    """
    Take a set of ISSNs and return only the valid normalized ones
    """
    valid_issns = set()
    for issn in issns:
        normalized = normalize_issn(issn)
        if normalized:
            valid_issns.add(normalized)
    return valid_issns

# %% [markdown]
# ## CrossRef diagnostics

# %%
def save_crossref_diagnostic(issn_to_data: Dict[str, List[Dict]], checkpoint_dir: Path):
    """Save CrossRef data to Excel for diagnostic purposes."""
    logger = logging.getLogger()
    
    # Create a list to hold the flattened data
    flattened_data = []
    
    for issn, data_list in issn_to_data.items():
        for data in data_list:
            message = data['data']['message']
            flattened_data.append({
                'issn': issn,
                'filename': data['filename'],
                'publisher': message.get('publisher', ''),
                'title': message.get('title', ''),
                'all_issns': message.get('ISSN', []),  # Now stored as a list
                'total_dois': message.get('counts', {}).get('total-dois', 0)
            })
    
    if flattened_data:
        df = pd.DataFrame(flattened_data)
        
        # Convert lists to strings for Excel storage
        for col in df.columns:
            if isinstance(df[col].iloc[0], list):
                df[col] = df[col].apply(lambda x: str(x) if x else '[]')
                
        output_file = checkpoint_dir / "crossref_data_diagnostic.xlsx"
        df.to_excel(output_file, index=False)
        logger.info(f"Saved CrossRef diagnostic data to {output_file}")
    else:
        logger.warning("No CrossRef data to save for diagnostics")

# %% [markdown]
# ## Load the Data

# %%
def load_harvard_data(excel_path: str) -> pd.DataFrame:
    """Load the Harvard journal data from Excel file."""
    logger = logging.getLogger()
    logger.info(f"Loading Harvard data from {excel_path}")
    df = pd.read_excel(excel_path)
    logger.info(f"Loaded {len(df)} rows from Harvard data")
    
    # Sample some ISSNs for validation
    sample_rows = df.head(5)
    logger.info("Sample of Harvard ISSN data:")
    for idx, row in sample_rows.iterrows():
        raw_issns = {col: row[col] for col in ['issn', 'issn_l', 'issn_print', 'issn_other_online'] if col in row and pd.notna(row[col])}
        normalized_issns = extract_issns_from_row(row)
        logger.info(f"Row {idx}:")
        logger.info(f"  Raw ISSNs: {raw_issns}")
        logger.info(f"  Normalized ISSNs: {normalized_issns}")
    return df


def load_crossref_data(json_dir: str) -> Dict[str, List[Dict]]:
    """
    Load all CrossRef JSON files and create a mapping of ISSN to file data.
    Returns a dictionary where keys are normalized ISSNs and values are lists of JSON data.
    """
    logger = logging.getLogger()
    issn_to_data = {}
    json_files = list(glob.glob(os.path.join(json_dir, "*.json")))
    logger.info(f"Found {len(json_files)} JSON files to process")
    
    for json_path in glob.glob(os.path.join(json_dir, "*.json")):
        try:
            with open(json_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                
            # Get ISSNs from both filename and JSON content and normalize them
            filename_issns = validate_issn_list(set(os.path.basename(json_path).replace('.json', '').split('; ')))
            json_issns = validate_issn_list(set(data.get('message', {}).get('ISSN', [])))
            all_issns = filename_issns.union(json_issns)
            
            # Enhanced logging for ISSN processing
            logger.debug(f"Processing {json_path}:")
            logger.debug(f"  - Raw filename ISSNs: {filename_issns}")
            logger.debug(f"  - Raw JSON ISSNs: {json_issns}")
            logger.debug(f"  - Normalized ISSNs: {all_issns}")
            
            if not all_issns:
                logger.warning(f"No valid ISSNs found in {json_path}")
            else:
                logger.debug(f"Found {len(all_issns)} valid ISSNs in {json_path}")
            
            for issn in all_issns:
                if issn not in issn_to_data:
                    issn_to_data[issn] = []
                issn_to_data[issn].append({
                    'data': data,
                    'filename': os.path.basename(json_path)
                })
                    
        except Exception as e:
            logger.error(f"Error processing {json_path}: {str(e)}")
            
    logger.info(f"Loaded data for {len(issn_to_data)} unique ISSNs")
    return issn_to_data

# %% [markdown]
# ## Extract ISSN from Harvard Data

# %%
def extract_issns_from_row(row: pd.Series) -> Set[str]:
    """
    Extract all ISSNs from a row, handling NaN values and normalizing them.
    """
    issn_columns = ['issn', 'issn_l', 'issn_print', 'issn_other_online']
    issns = set()
    
    for col in issn_columns:
        if col in row and pd.notna(row[col]):
            normalized = normalize_issn(str(row[col]).strip())
            if normalized:
                issns.add(normalized)
            
    return issns

# %% [markdown]
# ## Process CrossRef Matches

# %%
def extract_year_range(breakdown_data: List) -> tuple:
    """Extract start and end years from dois-by-issued-year data."""
    if not breakdown_data:
        return None, None
        
    years = [year for year, _ in breakdown_data]
    return min(years), max(years)

def process_crossref_matches(harvard_row: pd.Series, matched_data: List[Dict]) -> Dict:
    """Process all matching CrossRef records for a Harvard row."""
    publishers = set()
    titles = set()
    current_dois = set()
    backfile_dois = set()
    total_dois = set()
    subjects = set()
    all_issns = set()
    filenames = set()
    start_years = []
    end_years = []
    
    for match in matched_data:
        data = match['data']['message']
        
        publishers.add(data.get('publisher', ''))
        titles.add(data.get('title', ''))
        
        counts = data.get('counts', {})
        current_dois.add(str(counts.get('current-dois', 0)))
        backfile_dois.add(str(counts.get('backfile-dois', 0)))
        total_dois.add(str(counts.get('total-dois', 0)))
        
        # Add each subject individually to the set
        subjects.update(data.get('subjects', []))
        all_issns.update(data.get('ISSN', []))
        filenames.add(match['filename'])
        
        breakdown = data.get('breakdowns', {}).get('dois-by-issued-year', [])
        start_year, end_year = extract_year_range(breakdown)
        if start_year:
            start_years.append(start_year)
        if end_year:
            end_years.append(end_year)
    
    # Remove empty strings from sets
    publishers.discard('')
    titles.discard('')
    subjects.discard('')
    
    return {
        'crossref_publishers': list(publishers),
        'crossref_titles': list(titles),
        'crossref_current_dois': list(current_dois),
        'crossref_backfile_dois': list(backfile_dois),
        'crossref_total_dois': list(total_dois),
        'crossref_subjects': list(subjects),
        'crossref_issns': list(all_issns),
        'crossref_filenames': list(filenames),
        'crossref_start_year': min(start_years) if start_years else None,
        'crossref_end_year': max(end_years) if end_years else None
    }

# %% [markdown]
# ## Do the Work

# %%
def process_data(harvard_df: pd.DataFrame, crossref_data: Dict[str, List[Dict]], 
                checkpoint_dir: Path, batch_size: int = 1000) -> pd.DataFrame:
    """
    Process the Harvard data in batches, matching with CrossRef data.
    Includes all Harvard records and all CrossRef records in the output.
    Saves checkpoint files after each batch.
    Returns the final combined DataFrame.
    """
    logger = logging.getLogger()
    results = []
    total_rows = len(harvard_df)
    processed_crossref_issns = set()
    
    # First, process all Harvard records
    for start_idx in range(0, total_rows, batch_size):
        end_idx = min(start_idx + batch_size, total_rows)
        batch = harvard_df.iloc[start_idx:end_idx].copy()
        
        logger.info(f"Processing Harvard batch {start_idx} to {end_idx} of {total_rows}")
        
        for idx, row in batch.iterrows():
            row_issns = extract_issns_from_row(row)
            matched_data = []
            row_processed_issns = set()
            
            for issn in row_issns:
                normalized_issn = normalize_issn(issn)
                if normalized_issn and normalized_issn in crossref_data:
                    matched_data.extend(crossref_data[normalized_issn])
                    row_processed_issns.add(normalized_issn)
            
            processed_crossref_issns.update(row_processed_issns)
            
            if matched_data:
                crossref_info = process_crossref_matches(row, matched_data)
                results.append({**row.to_dict(), **crossref_info})
            else:
                # Include Harvard record with empty CrossRef fields
                empty_crossref = {
                    'crossref_publishers': [],
                    'crossref_titles': [],
                    'crossref_current_dois': [],
                    'crossref_backfile_dois': [],
                    'crossref_total_dois': [],
                    'crossref_subjects': [],
                    'crossref_issns': [],
                    'crossref_filenames': [],
                    'crossref_start_year': None,
                    'crossref_end_year': None
                }
                results.append({**row.to_dict(), **empty_crossref})
        
        # Save checkpoint after each batch
        if results:
            checkpoint_df = pd.DataFrame(results)
            checkpoint_file = checkpoint_dir / f"harvard_crossref_match_checkpoint_{end_idx}.xlsx"
            
            # Convert lists to strings for Excel storage
            for col in checkpoint_df.columns:
                if col in checkpoint_df and len(checkpoint_df) > 0:
                    if isinstance(checkpoint_df[col].iloc[0], list):
                        checkpoint_df[col] = checkpoint_df[col].apply(lambda x: str(x) if x else '[]')
            
            checkpoint_df.to_excel(checkpoint_file, index=False)
            logger.info(f"Saved checkpoint file: {checkpoint_file}")
    
    # Now process remaining CrossRef records that weren't matched to any Harvard record
    logger.info(f"Processing unmatched CrossRef records")
    unmatched_issns = set(crossref_data.keys()) - processed_crossref_issns
    logger.info(f"Found {len(unmatched_issns)} unmatched CrossRef ISSNs")
    
    # Process unmatched CrossRef records in batches
    unmatched_list = list(unmatched_issns)
    unmatched_batch_size = 5000  # Can be adjusted based on memory constraints
    
    for start_idx in range(0, len(unmatched_list), unmatched_batch_size):
        end_idx = min(start_idx + unmatched_batch_size, len(unmatched_list))
        batch_issns = unmatched_list[start_idx:end_idx]
        
        logger.info(f"Processing unmatched CrossRef batch {start_idx} to {end_idx} of {len(unmatched_list)}")
        
        for issn in batch_issns:
            if issn in crossref_data:
                matched_data = crossref_data[issn]
                
                # Process the CrossRef data
                crossref_info = process_crossref_matches(pd.Series(), matched_data)
                
                # Create a new row with empty Harvard data and the CrossRef data
                # Get the Harvard column names from the first result, if available
                if results:
                    harvard_columns = [col for col in results[0].keys() 
                                    if not col.startswith('crossref_')]
                    
                    # Create empty Harvard data
                    empty_harvard = {col: None for col in harvard_columns}
                    
                    # Add the ISSN to appropriate Harvard fields for reference
                    empty_harvard['issn'] = issn
                    
                    # Add CrossRef data to main columns - assuming standard column order:
                    # title (B), publisher (C), start_year (D), end_year (E), format (F)
                    if crossref_info['crossref_titles'] and len(crossref_info['crossref_titles']) > 0:
                        empty_harvard['title'] = crossref_info['crossref_titles'][0]
                    
                    if crossref_info['crossref_publishers'] and len(crossref_info['crossref_publishers']) > 0:
                        empty_harvard['publisher'] = crossref_info['crossref_publishers'][0]
                    
                    empty_harvard['start_year'] = crossref_info['crossref_start_year']
                    empty_harvard['end_year'] = crossref_info['crossref_end_year']
                    
                    # Add "online" format
                    empty_harvard['format'] = ['online']
                    
                    # Combine with CrossRef data
                    results.append({**empty_harvard, **crossref_info})
        
        # Save checkpoint after each batch of unmatched CrossRef records
        if results:
            checkpoint_df = pd.DataFrame(results)
            checkpoint_file = checkpoint_dir / f"harvard_crossref_match_checkpoint_unmatched_{end_idx}.xlsx"
            
            # Convert lists to strings for Excel storage
            for col in checkpoint_df.columns:
                if col in checkpoint_df and len(checkpoint_df) > 0:
                    if isinstance(checkpoint_df[col].iloc[0], list):
                        checkpoint_df[col] = checkpoint_df[col].apply(lambda x: str(x) if x else '[]')
            
            checkpoint_df.to_excel(checkpoint_file, index=False)
            logger.info(f"Saved unmatched CrossRef checkpoint file: {checkpoint_file}")
    
    # Return the final DataFrame
    if results:
        final_df = pd.DataFrame(results)
        return final_df
    return None

# %% [markdown]
# ## Main

# %%
def main():
    """Main function to run the analysis."""
    logger = setup_logging()
    checkpoint_dir = create_checkpoint_dir()
    
    try:
        # Load Harvard data
        harvard_df = load_harvard_data(HARVARD_MD_FILE)
        logger.info(f"Loaded {len(harvard_df)} Harvard records")
        
        # Load CrossRef data
        crossref_data = load_crossref_data(CROSSREF_MD_DIR)
        logger.info(f"Loaded CrossRef data with {len(crossref_data)} unique ISSNs")
        
        # Log some sample matches for debugging
        sample_issns = list(harvard_df['issn'].dropna().head())
        logger.info("Checking sample ISSNs for matches:")
        for issn in sample_issns:
            normalized = normalize_issn(str(issn))
            if normalized in crossref_data:
                logger.info(f"Found match for ISSN {issn} (normalized: {normalized})")
            else:
                logger.info(f"No match for ISSN {issn} (normalized: {normalized})")
        
        # Save diagnostic data
        save_crossref_diagnostic(crossref_data, checkpoint_dir)
        
        # Process data with checkpoints
        final_df = process_data(harvard_df, crossref_data, checkpoint_dir)
        
        if final_df is not None and not final_df.empty:
            # Log match statistics
            match_count = len(final_df[final_df['crossref_filenames'].str.len() > 2])  # > 2 because empty list is '[]'
            logger.info(f"Found {match_count} records with CrossRef matches out of {len(final_df)} total records")
            
            # Save final output
            final_output = checkpoint_dir / f"{OUTPUT_MD_FILE_ROOT}.xlsx"
            final_df.to_excel(final_output, index=False)
            logger.info(f"Analysis complete. Final output saved to: {final_output}")
        else:
            logger.warning("No matches found in the data - this is unexpected if checkpoint files exist")
            logger.info("Please check:")
            logger.info("1. The Harvard ISSN columns contain valid ISSNs")
            logger.info("2. The CrossRef data contains matching ISSNs")
            logger.info("3. The ISSN normalization is working as expected")

        if final_df is not None and not final_df.empty:
            # Log match statistics
            match_count = len(final_df[final_df['crossref_filenames'].str.len() > 2])  # > 2 because empty list is '[]'
            harvard_count = len(final_df[~final_df['title'].isna()])  # Count rows with Harvard title
            crossref_only_count = len(final_df[final_df['title'].isna()])  # Count rows without Harvard title (CrossRef only)
            
            logger.info(f"Found {match_count} records with CrossRef matches out of {harvard_count} Harvard records")
            logger.info(f"Added {crossref_only_count} CrossRef-only records (not in Harvard data)")
            logger.info(f"Total records in output: {len(final_df)}")

    except Exception as e:
        logger.error(f"Error in main process: {str(e)}", exc_info=True)

if __name__ == "__main__":
    main()
# Out:
# Loading Harvard data from Output Data/Harvard Data with LCC Subjects and only ISSN.xlsx
# Loaded 303615 rows from Harvard data
# Sample of Harvard ISSN data:
# Row 0:
#   Raw ISSNs: {'issn': '0333-6883', 'issn_l': '0333-6883'}
#   Normalized ISSNs: {'03336883'}
# Row 1:
#   Raw ISSNs: {'issn': '0041-7750', 'issn_l': '0041-7750'}
#   Normalized ISSNs: {'00417750'}
# Row 2:
#   Raw ISSNs: {'issn': '0334-4738'}
#   Normalized ISSNs: {'03344738'}
# Row 3:
#   Raw ISSNs: {'issn': '0073-4217', 'issn_l': '0073-4217'}
#   Normalized ISSNs: {'00734217'}
# Row 4:
#   Raw ISSNs: {'issn': '0792-7932'}
#   Normalized ISSNs: {'07927932'}
# Loaded 303615 Harvard records
# Found 180222 JSON files to process
# Loaded data for 180253 unique ISSNs
# Loaded CrossRef data with 180253 unique ISSNs
# Checking sample ISSNs for matches:
# No match for ISSN 0333-6883 (normalized: 03336883)
# No match for ISSN 0041-7750 (normalized: 00417750)
# No match for ISSN 0334-4738 (normalized: 03344738)
# No match for ISSN 0073-4217 (normalized: 00734217)
# No match for ISSN 0792-7932 (normalized: 07927932)
# Saved CrossRef diagnostic data to Harvard Analysis Checkpoints\crossref_data_diagnostic.xlsx
# Processing Harvard batch 0 to 1000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_1000.xlsx
# Processing Harvard batch 1000 to 2000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_2000.xlsx
# Processing Harvard batch 2000 to 3000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_3000.xlsx
# Processing Harvard batch 3000 to 4000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_4000.xlsx
# Processing Harvard batch 4000 to 5000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_5000.xlsx
# Processing Harvard batch 5000 to 6000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_6000.xlsx
# Processing Harvard batch 6000 to 7000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_7000.xlsx
# Processing Harvard batch 7000 to 8000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_8000.xlsx
# Processing Harvard batch 8000 to 9000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_9000.xlsx
# Processing Harvard batch 9000 to 10000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_10000.xlsx
# Processing Harvard batch 10000 to 11000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_11000.xlsx
# Processing Harvard batch 11000 to 12000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_12000.xlsx
# Processing Harvard batch 12000 to 13000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_13000.xlsx
# Processing Harvard batch 13000 to 14000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_14000.xlsx
# Processing Harvard batch 14000 to 15000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_15000.xlsx
# Processing Harvard batch 15000 to 16000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_16000.xlsx
# Processing Harvard batch 16000 to 17000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_17000.xlsx
# Processing Harvard batch 17000 to 18000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_18000.xlsx
# Processing Harvard batch 18000 to 19000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_19000.xlsx
# Processing Harvard batch 19000 to 20000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_20000.xlsx
# Processing Harvard batch 20000 to 21000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_21000.xlsx
# Processing Harvard batch 21000 to 22000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_22000.xlsx
# Processing Harvard batch 22000 to 23000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_23000.xlsx
# Processing Harvard batch 23000 to 24000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_24000.xlsx
# Processing Harvard batch 24000 to 25000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_25000.xlsx
# Processing Harvard batch 25000 to 26000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_26000.xlsx
# Processing Harvard batch 26000 to 27000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_27000.xlsx
# Processing Harvard batch 27000 to 28000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_28000.xlsx
# Processing Harvard batch 28000 to 29000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_29000.xlsx
# Processing Harvard batch 29000 to 30000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_30000.xlsx
# Processing Harvard batch 30000 to 31000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_31000.xlsx
# Processing Harvard batch 31000 to 32000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_32000.xlsx
# Processing Harvard batch 32000 to 33000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_33000.xlsx
# Processing Harvard batch 33000 to 34000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_34000.xlsx
# Processing Harvard batch 34000 to 35000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_35000.xlsx
# Processing Harvard batch 35000 to 36000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_36000.xlsx
# Processing Harvard batch 36000 to 37000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_37000.xlsx
# Processing Harvard batch 37000 to 38000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_38000.xlsx
# Processing Harvard batch 38000 to 39000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_39000.xlsx
# Processing Harvard batch 39000 to 40000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_40000.xlsx
# Processing Harvard batch 40000 to 41000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_41000.xlsx
# Processing Harvard batch 41000 to 42000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_42000.xlsx
# Processing Harvard batch 42000 to 43000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_43000.xlsx
# Processing Harvard batch 43000 to 44000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_44000.xlsx
# Processing Harvard batch 44000 to 45000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_45000.xlsx
# Processing Harvard batch 45000 to 46000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_46000.xlsx
# Processing Harvard batch 46000 to 47000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_47000.xlsx
# Processing Harvard batch 47000 to 48000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_48000.xlsx
# Processing Harvard batch 48000 to 49000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_49000.xlsx
# Processing Harvard batch 49000 to 50000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_50000.xlsx
# Processing Harvard batch 50000 to 51000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_51000.xlsx
# Processing Harvard batch 51000 to 52000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_52000.xlsx
# Processing Harvard batch 52000 to 53000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_53000.xlsx
# Processing Harvard batch 53000 to 54000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_54000.xlsx
# Processing Harvard batch 54000 to 55000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_55000.xlsx
# Processing Harvard batch 55000 to 56000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_56000.xlsx
# Processing Harvard batch 56000 to 57000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_57000.xlsx
# Processing Harvard batch 57000 to 58000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_58000.xlsx
# Processing Harvard batch 58000 to 59000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_59000.xlsx
# Processing Harvard batch 59000 to 60000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_60000.xlsx
# Processing Harvard batch 60000 to 61000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_61000.xlsx
# Processing Harvard batch 61000 to 62000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_62000.xlsx
# Processing Harvard batch 62000 to 63000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_63000.xlsx
# Processing Harvard batch 63000 to 64000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_64000.xlsx
# Processing Harvard batch 64000 to 65000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_65000.xlsx
# Processing Harvard batch 65000 to 66000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_66000.xlsx
# Processing Harvard batch 66000 to 67000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_67000.xlsx
# Processing Harvard batch 67000 to 68000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_68000.xlsx
# Processing Harvard batch 68000 to 69000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_69000.xlsx
# Processing Harvard batch 69000 to 70000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_70000.xlsx
# Processing Harvard batch 70000 to 71000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_71000.xlsx
# Processing Harvard batch 71000 to 72000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_72000.xlsx
# Processing Harvard batch 72000 to 73000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_73000.xlsx
# Processing Harvard batch 73000 to 74000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_74000.xlsx
# Processing Harvard batch 74000 to 75000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_75000.xlsx
# Processing Harvard batch 75000 to 76000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_76000.xlsx
# Processing Harvard batch 76000 to 77000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_77000.xlsx
# Processing Harvard batch 77000 to 78000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_78000.xlsx
# Processing Harvard batch 78000 to 79000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_79000.xlsx
# Processing Harvard batch 79000 to 80000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_80000.xlsx
# Processing Harvard batch 80000 to 81000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_81000.xlsx
# Processing Harvard batch 81000 to 82000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_82000.xlsx
# Processing Harvard batch 82000 to 83000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_83000.xlsx
# Processing Harvard batch 83000 to 84000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_84000.xlsx
# Processing Harvard batch 84000 to 85000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_85000.xlsx
# Processing Harvard batch 85000 to 86000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_86000.xlsx
# Processing Harvard batch 86000 to 87000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_87000.xlsx
# Processing Harvard batch 87000 to 88000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_88000.xlsx
# Processing Harvard batch 88000 to 89000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_89000.xlsx
# Processing Harvard batch 89000 to 90000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_90000.xlsx
# Processing Harvard batch 90000 to 91000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_91000.xlsx
# Processing Harvard batch 91000 to 92000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_92000.xlsx
# Processing Harvard batch 92000 to 93000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_93000.xlsx
# Processing Harvard batch 93000 to 94000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_94000.xlsx
# Processing Harvard batch 94000 to 95000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_95000.xlsx
# Processing Harvard batch 95000 to 96000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_96000.xlsx
# Processing Harvard batch 96000 to 97000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_97000.xlsx
# Processing Harvard batch 97000 to 98000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_98000.xlsx
# Processing Harvard batch 98000 to 99000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_99000.xlsx
# Processing Harvard batch 99000 to 100000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_100000.xlsx
# Processing Harvard batch 100000 to 101000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_101000.xlsx
# Processing Harvard batch 101000 to 102000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_102000.xlsx
# Processing Harvard batch 102000 to 103000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_103000.xlsx
# Processing Harvard batch 103000 to 104000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_104000.xlsx
# Processing Harvard batch 104000 to 105000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_105000.xlsx
# Processing Harvard batch 105000 to 106000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_106000.xlsx
# Processing Harvard batch 106000 to 107000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_107000.xlsx
# Processing Harvard batch 107000 to 108000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_108000.xlsx
# Processing Harvard batch 108000 to 109000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_109000.xlsx
# Processing Harvard batch 109000 to 110000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_110000.xlsx
# Processing Harvard batch 110000 to 111000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_111000.xlsx
# Processing Harvard batch 111000 to 112000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_112000.xlsx
# Processing Harvard batch 112000 to 113000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_113000.xlsx
# Processing Harvard batch 113000 to 114000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_114000.xlsx
# Processing Harvard batch 114000 to 115000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_115000.xlsx
# Processing Harvard batch 115000 to 116000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_116000.xlsx
# Processing Harvard batch 116000 to 117000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_117000.xlsx
# Processing Harvard batch 117000 to 118000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_118000.xlsx
# Processing Harvard batch 118000 to 119000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_119000.xlsx
# Processing Harvard batch 119000 to 120000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_120000.xlsx
# Processing Harvard batch 120000 to 121000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_121000.xlsx
# Processing Harvard batch 121000 to 122000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_122000.xlsx
# Processing Harvard batch 122000 to 123000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_123000.xlsx
# Processing Harvard batch 123000 to 124000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_124000.xlsx
# Processing Harvard batch 124000 to 125000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_125000.xlsx
# Processing Harvard batch 125000 to 126000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_126000.xlsx
# Processing Harvard batch 126000 to 127000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_127000.xlsx
# Processing Harvard batch 127000 to 128000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_128000.xlsx
# Processing Harvard batch 128000 to 129000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_129000.xlsx
# Processing Harvard batch 129000 to 130000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_130000.xlsx
# Processing Harvard batch 130000 to 131000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_131000.xlsx
# Processing Harvard batch 131000 to 132000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_132000.xlsx
# Processing Harvard batch 132000 to 133000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_133000.xlsx
# Processing Harvard batch 133000 to 134000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_134000.xlsx
# Processing Harvard batch 134000 to 135000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_135000.xlsx
# Processing Harvard batch 135000 to 136000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_136000.xlsx
# Processing Harvard batch 136000 to 137000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_137000.xlsx
# Processing Harvard batch 137000 to 138000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_138000.xlsx
# Processing Harvard batch 138000 to 139000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_139000.xlsx
# Processing Harvard batch 139000 to 140000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_140000.xlsx
# Processing Harvard batch 140000 to 141000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_141000.xlsx
# Processing Harvard batch 141000 to 142000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_142000.xlsx
# Processing Harvard batch 142000 to 143000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_143000.xlsx
# Processing Harvard batch 143000 to 144000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_144000.xlsx
# Processing Harvard batch 144000 to 145000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_145000.xlsx
# Processing Harvard batch 145000 to 146000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_146000.xlsx
# Processing Harvard batch 146000 to 147000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_147000.xlsx
# Processing Harvard batch 147000 to 148000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_148000.xlsx
# Processing Harvard batch 148000 to 149000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_149000.xlsx
# Processing Harvard batch 149000 to 150000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_150000.xlsx
# Processing Harvard batch 150000 to 151000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_151000.xlsx
# Processing Harvard batch 151000 to 152000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_152000.xlsx
# Processing Harvard batch 152000 to 153000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_153000.xlsx
# Processing Harvard batch 153000 to 154000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_154000.xlsx
# Processing Harvard batch 154000 to 155000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_155000.xlsx
# Processing Harvard batch 155000 to 156000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_156000.xlsx
# Processing Harvard batch 156000 to 157000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_157000.xlsx
# Processing Harvard batch 157000 to 158000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_158000.xlsx
# Processing Harvard batch 158000 to 159000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_159000.xlsx
# Processing Harvard batch 159000 to 160000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_160000.xlsx
# Processing Harvard batch 160000 to 161000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_161000.xlsx
# Processing Harvard batch 161000 to 162000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_162000.xlsx
# Processing Harvard batch 162000 to 163000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_163000.xlsx
# Processing Harvard batch 163000 to 164000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_164000.xlsx
# Processing Harvard batch 164000 to 165000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_165000.xlsx
# Processing Harvard batch 165000 to 166000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_166000.xlsx
# Processing Harvard batch 166000 to 167000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_167000.xlsx
# Processing Harvard batch 167000 to 168000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_168000.xlsx
# Processing Harvard batch 168000 to 169000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_169000.xlsx
# Processing Harvard batch 169000 to 170000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_170000.xlsx
# Processing Harvard batch 170000 to 171000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_171000.xlsx
# Processing Harvard batch 171000 to 172000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_172000.xlsx
# Processing Harvard batch 172000 to 173000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_173000.xlsx
# Processing Harvard batch 173000 to 174000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_174000.xlsx
# Processing Harvard batch 174000 to 175000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_175000.xlsx
# Processing Harvard batch 175000 to 176000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_176000.xlsx
# Processing Harvard batch 176000 to 177000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_177000.xlsx
# Processing Harvard batch 177000 to 178000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_178000.xlsx
# Processing Harvard batch 178000 to 179000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_179000.xlsx
# Processing Harvard batch 179000 to 180000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_180000.xlsx
# Processing Harvard batch 180000 to 181000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_181000.xlsx
# Processing Harvard batch 181000 to 182000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_182000.xlsx
# Processing Harvard batch 182000 to 183000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_183000.xlsx
# Processing Harvard batch 183000 to 184000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_184000.xlsx
# Processing Harvard batch 184000 to 185000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_185000.xlsx
# Processing Harvard batch 185000 to 186000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_186000.xlsx
# Processing Harvard batch 186000 to 187000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_187000.xlsx
# Processing Harvard batch 187000 to 188000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_188000.xlsx
# Processing Harvard batch 188000 to 189000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_189000.xlsx
# Processing Harvard batch 189000 to 190000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_190000.xlsx
# Processing Harvard batch 190000 to 191000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_191000.xlsx
# Processing Harvard batch 191000 to 192000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_192000.xlsx
# Processing Harvard batch 192000 to 193000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_193000.xlsx
# Processing Harvard batch 193000 to 194000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_194000.xlsx
# Processing Harvard batch 194000 to 195000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_195000.xlsx
# Processing Harvard batch 195000 to 196000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_196000.xlsx
# Processing Harvard batch 196000 to 197000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_197000.xlsx
# Processing Harvard batch 197000 to 198000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_198000.xlsx
# Processing Harvard batch 198000 to 199000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_199000.xlsx
# Processing Harvard batch 199000 to 200000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_200000.xlsx
# Processing Harvard batch 200000 to 201000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_201000.xlsx
# Processing Harvard batch 201000 to 202000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_202000.xlsx
# Processing Harvard batch 202000 to 203000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_203000.xlsx
# Processing Harvard batch 203000 to 204000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_204000.xlsx
# Processing Harvard batch 204000 to 205000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_205000.xlsx
# Processing Harvard batch 205000 to 206000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_206000.xlsx
# Processing Harvard batch 206000 to 207000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_207000.xlsx
# Processing Harvard batch 207000 to 208000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_208000.xlsx
# Processing Harvard batch 208000 to 209000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_209000.xlsx
# Processing Harvard batch 209000 to 210000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_210000.xlsx
# Processing Harvard batch 210000 to 211000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_211000.xlsx
# Processing Harvard batch 211000 to 212000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_212000.xlsx
# Processing Harvard batch 212000 to 213000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_213000.xlsx
# Processing Harvard batch 213000 to 214000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_214000.xlsx
# Processing Harvard batch 214000 to 215000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_215000.xlsx
# Processing Harvard batch 215000 to 216000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_216000.xlsx
# Processing Harvard batch 216000 to 217000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_217000.xlsx
# Processing Harvard batch 217000 to 218000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_218000.xlsx
# Processing Harvard batch 218000 to 219000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_219000.xlsx
# Processing Harvard batch 219000 to 220000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_220000.xlsx
# Processing Harvard batch 220000 to 221000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_221000.xlsx
# Processing Harvard batch 221000 to 222000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_222000.xlsx
# Processing Harvard batch 222000 to 223000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_223000.xlsx
# Processing Harvard batch 223000 to 224000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_224000.xlsx
# Processing Harvard batch 224000 to 225000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_225000.xlsx
# Processing Harvard batch 225000 to 226000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_226000.xlsx
# Processing Harvard batch 226000 to 227000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_227000.xlsx
# Processing Harvard batch 227000 to 228000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_228000.xlsx
# Processing Harvard batch 228000 to 229000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_229000.xlsx
# Processing Harvard batch 229000 to 230000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_230000.xlsx
# Processing Harvard batch 230000 to 231000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_231000.xlsx
# Processing Harvard batch 231000 to 232000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_232000.xlsx
# Processing Harvard batch 232000 to 233000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_233000.xlsx
# Processing Harvard batch 233000 to 234000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_234000.xlsx
# Processing Harvard batch 234000 to 235000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_235000.xlsx
# Processing Harvard batch 235000 to 236000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_236000.xlsx
# Processing Harvard batch 236000 to 237000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_237000.xlsx
# Processing Harvard batch 237000 to 238000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_238000.xlsx
# Processing Harvard batch 238000 to 239000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_239000.xlsx
# Processing Harvard batch 239000 to 240000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_240000.xlsx
# Processing Harvard batch 240000 to 241000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_241000.xlsx
# Processing Harvard batch 241000 to 242000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_242000.xlsx
# Processing Harvard batch 242000 to 243000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_243000.xlsx
# Processing Harvard batch 243000 to 244000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_244000.xlsx
# Processing Harvard batch 244000 to 245000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_245000.xlsx
# Processing Harvard batch 245000 to 246000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_246000.xlsx
# Processing Harvard batch 246000 to 247000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_247000.xlsx
# Processing Harvard batch 247000 to 248000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_248000.xlsx
# Processing Harvard batch 248000 to 249000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_249000.xlsx
# Processing Harvard batch 249000 to 250000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_250000.xlsx
# Processing Harvard batch 250000 to 251000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_251000.xlsx
# Processing Harvard batch 251000 to 252000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_252000.xlsx
# Processing Harvard batch 252000 to 253000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_253000.xlsx
# Processing Harvard batch 253000 to 254000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_254000.xlsx
# Processing Harvard batch 254000 to 255000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_255000.xlsx
# Processing Harvard batch 255000 to 256000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_256000.xlsx
# Processing Harvard batch 256000 to 257000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_257000.xlsx
# Processing Harvard batch 257000 to 258000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_258000.xlsx
# Processing Harvard batch 258000 to 259000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_259000.xlsx
# Processing Harvard batch 259000 to 260000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_260000.xlsx
# Processing Harvard batch 260000 to 261000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_261000.xlsx
# Processing Harvard batch 261000 to 262000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_262000.xlsx
# Processing Harvard batch 262000 to 263000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_263000.xlsx
# Processing Harvard batch 263000 to 264000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_264000.xlsx
# Processing Harvard batch 264000 to 265000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_265000.xlsx
# Processing Harvard batch 265000 to 266000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_266000.xlsx
# Processing Harvard batch 266000 to 267000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_267000.xlsx
# Processing Harvard batch 267000 to 268000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_268000.xlsx
# Processing Harvard batch 268000 to 269000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_269000.xlsx
# Processing Harvard batch 269000 to 270000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_270000.xlsx
# Processing Harvard batch 270000 to 271000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_271000.xlsx
# Processing Harvard batch 271000 to 272000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_272000.xlsx
# Processing Harvard batch 272000 to 273000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_273000.xlsx
# Processing Harvard batch 273000 to 274000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_274000.xlsx
# Processing Harvard batch 274000 to 275000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_275000.xlsx
# Processing Harvard batch 275000 to 276000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_276000.xlsx
# Processing Harvard batch 276000 to 277000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_277000.xlsx
# Processing Harvard batch 277000 to 278000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_278000.xlsx
# Processing Harvard batch 278000 to 279000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_279000.xlsx
# Processing Harvard batch 279000 to 280000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_280000.xlsx
# Processing Harvard batch 280000 to 281000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_281000.xlsx
# Processing Harvard batch 281000 to 282000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_282000.xlsx
# Processing Harvard batch 282000 to 283000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_283000.xlsx
# Processing Harvard batch 283000 to 284000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_284000.xlsx
# Processing Harvard batch 284000 to 285000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_285000.xlsx
# Processing Harvard batch 285000 to 286000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_286000.xlsx
# Processing Harvard batch 286000 to 287000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_287000.xlsx
# Processing Harvard batch 287000 to 288000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_288000.xlsx
# Processing Harvard batch 288000 to 289000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_289000.xlsx
# Processing Harvard batch 289000 to 290000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_290000.xlsx
# Processing Harvard batch 290000 to 291000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_291000.xlsx
# Processing Harvard batch 291000 to 292000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_292000.xlsx
# Processing Harvard batch 292000 to 293000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_293000.xlsx
# Processing Harvard batch 293000 to 294000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_294000.xlsx
# Processing Harvard batch 294000 to 295000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_295000.xlsx
# Processing Harvard batch 295000 to 296000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_296000.xlsx
# Processing Harvard batch 296000 to 297000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_297000.xlsx
# Processing Harvard batch 297000 to 298000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_298000.xlsx
# Processing Harvard batch 298000 to 299000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_299000.xlsx
# Processing Harvard batch 299000 to 300000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_300000.xlsx
# Processing Harvard batch 300000 to 301000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_301000.xlsx
# Processing Harvard batch 301000 to 302000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_302000.xlsx
# Processing Harvard batch 302000 to 303000 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_303000.xlsx
# Processing Harvard batch 303000 to 303615 of 303615
# Saved checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_303615.xlsx
# Processing unmatched CrossRef records
# Found 99447 unmatched CrossRef ISSNs
# Processing unmatched CrossRef batch 0 to 5000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_5000.xlsx
# Processing unmatched CrossRef batch 5000 to 10000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_10000.xlsx
# Processing unmatched CrossRef batch 10000 to 15000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_15000.xlsx
# Processing unmatched CrossRef batch 15000 to 20000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_20000.xlsx
# Processing unmatched CrossRef batch 20000 to 25000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_25000.xlsx
# Processing unmatched CrossRef batch 25000 to 30000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_30000.xlsx
# Processing unmatched CrossRef batch 30000 to 35000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_35000.xlsx
# Processing unmatched CrossRef batch 35000 to 40000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_40000.xlsx
# Processing unmatched CrossRef batch 40000 to 45000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_45000.xlsx
# Processing unmatched CrossRef batch 45000 to 50000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_50000.xlsx
# Processing unmatched CrossRef batch 50000 to 55000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_55000.xlsx
# Processing unmatched CrossRef batch 55000 to 60000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_60000.xlsx
# Processing unmatched CrossRef batch 60000 to 65000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_65000.xlsx
# Processing unmatched CrossRef batch 65000 to 70000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_70000.xlsx
# Processing unmatched CrossRef batch 70000 to 75000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_75000.xlsx
# Processing unmatched CrossRef batch 75000 to 80000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_80000.xlsx
# Processing unmatched CrossRef batch 80000 to 85000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_85000.xlsx
# Processing unmatched CrossRef batch 85000 to 90000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_90000.xlsx
# Processing unmatched CrossRef batch 90000 to 95000 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_95000.xlsx
# Processing unmatched CrossRef batch 95000 to 99447 of 99447
# Saved unmatched CrossRef checkpoint file: Harvard Analysis Checkpoints\harvard_crossref_match_checkpoint_unmatched_99447.xlsx
# Found 3231 records with CrossRef matches out of 403062 total records
# Analysis complete. Final output saved to: Harvard Analysis Checkpoints\harvard_crossref_match_final.xlsx
# Found 3231 records with CrossRef matches out of 403059 Harvard records
# Added 3 CrossRef-only records (not in Harvard data)
# Total records in output: 403062

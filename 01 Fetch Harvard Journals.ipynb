# %% [markdown]
# # Fetch all the Harvard records for journals or serials

# %% [markdown]
# ## Set things up, import -- logging, etc.

# %%
import xml.etree.ElementTree as ET
import os
import re
from xml.dom import minidom
import requests
import time
import logging
from itertools import product
from datetime import datetime

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s')

#Some Global Variables
OUTPUT_DIR = "mods_records"
OVERWRITE_FILES = False
BASE_URL = "https://api.lib.harvard.edu/v2/items"
LAST_REQUEST_TIME = 0

# %% [markdown]
# # Set up some Logging

# %%
# Create logs directory if it doesn't exist
os.makedirs('logs', exist_ok=True)

# Create formatters for different levels of detail
brief_formatter = logging.Formatter('%(message)s')  # Even more concise for console
verbose_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Create and configure handlers
log_filename = f"logs/harvard_fetch_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"

# Clear any existing handlers
logger = logging.getLogger()
for handler in logger.handlers[:]:
    logger.removeHandler(handler)

# File handler - gets everything with full detail
file_handler = logging.FileHandler(log_filename)
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(verbose_formatter)

# Console handler - gets just the important stuff briefly
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(brief_formatter)

# Configure root logger
logger.setLevel(logging.DEBUG)  # Capture all levels
logger.addHandler(file_handler)
logger.addHandler(console_handler)

# %% [markdown]
# # Other Functions

# %%
def rate_limit_wait():
    """Ensure at least 1 second between requests"""
    global LAST_REQUEST_TIME
    time_since_last = time.time() - LAST_REQUEST_TIME
    if time_since_last < 1:
        logging.debug(f"Rate limiting: waiting {1 - time_since_last:.2f} seconds")
        time.sleep(1 - time_since_last)
    LAST_REQUEST_TIME = time.time()


def fetch_mods_data(params):
    """Fetch MODS XML data from the API with rate limiting"""
    rate_limit_wait()
    try:
        logging.debug(f"Making API request to {BASE_URL}")
        logging.debug(f"Request parameters: {params}")
        
        response = requests.get(BASE_URL, params=params)
        response.raise_for_status()
        
        logging.debug(f"Response status code: {response.status_code}")
        return response.text
    except requests.exceptions.RequestException as e:
        logging.error(f"API request failed: {str(e)}")
        logging.debug(f"Full error details: {e}", exc_info=True)
        return None


def get_result_count(params):
    """Get the total number of results for a query"""
    xml_data = fetch_mods_data(params)
    if xml_data:
        try:
            root = ET.fromstring(xml_data)
            num_found = root.find(".//{*}numFound")
            if num_found is not None:
                count = int(num_found.text)
                logging.debug(f"Query returned {count} total results")
                return count
            logging.warning("No numFound element in response")
        except ET.ParseError as e:
            logging.error(f"Failed to parse XML response: {e}")
            logging.debug("XML Parse Error Details:", exc_info=True)
    return 0


def fetch_with_prefix(prefix, record_type='serial'):
    """Fetch records that match a specific record identifier prefix"""
    logging.debug(f"Starting fetch_with_prefix operation:")
    logging.debug(f"Prefix: {prefix}")
    logging.debug(f"Record type: {record_type}")
    logging.debug(f"Output directory: {OUTPUT_DIR}")
    
    params = {
        'recordIdentifier': f"{prefix}*",
        'limit': 250
    }
    
    if record_type == 'serial':
        params['issuance'] = 'serial'
    else:  # periodical
        params['genre'] = 'periodicals'
        
    total_results = get_result_count(params)
    
    if total_results > 0:
        logging.info(f"Found {total_results} {record_type} records for prefix {prefix}")
    
    logging.debug(f"Query parameters: {params}")
    
    if total_results == 0:
        logging.debug(f"Skipping prefix {prefix} - no results")
        return
        
    fetch_all_pages(params, total_results)


def fetch_all_pages(params, total_results):
    """Fetch all pages of results with cursor pagination if needed"""
    records_processed = 0
    batch_number = 0
    last_progress_report = 0
    progress_interval = 1000  # Only show progress every 1000 records
    
    logging.debug(f"Initial parameters: {params}")
    
    if total_results <= params.get('limit', 250):
        logging.debug("Single page fetch - no pagination needed")
        xml_data = fetch_mods_data(params)
        if xml_data:
            process_and_save_records(xml_data)
        return
    
    params['cursor'] = '*'
    
    while records_processed < total_results:
        batch_number += 1
        logging.debug(f"Fetching batch {batch_number}")
        
        xml_data = fetch_mods_data(params)
        if not xml_data:
            logging.error("Failed to fetch data, breaking pagination loop")
            break
            
        root = ET.fromstring(xml_data)
        next_cursor = root.find(".//{*}nextCursor")
        
        saved, skipped, errors = save_mods_records(xml_data, OUTPUT_DIR)
        records_processed += saved + skipped
        
        # Only show progress in console at intervals
        if records_processed - last_progress_report >= progress_interval:
            logging.info(f"Progress: {records_processed}/{total_results} records ({(records_processed/total_results*100):.1f}%)")
            last_progress_report = records_processed
        
        # Detailed batch information goes to debug
        logging.debug(f"Batch {batch_number} complete:")
        logging.debug(f"- Records saved: {saved}")
        logging.debug(f"- Records skipped: {skipped}")
        
        if errors:
            for error in errors:
                logging.error(f"Batch {batch_number} error: {error}")
        
        if next_cursor is None or records_processed >= total_results:
            logging.debug("Pagination complete")
            break
            
        params['cursor'] = next_cursor.text
        logging.debug(f"Next cursor: {params['cursor']}")


def systematic_fetch(start_digits='99', digit_positions=4):
    """Systematically fetch records by trying different numeric prefixes"""
    total_prefixes = 10 ** digit_positions
    current_prefix = 0
    
    logging.info(f"Starting systematic fetch with {total_prefixes} prefixes...")
    
    for digits in product(range(10), repeat=digit_positions):
        current_prefix += 1
        prefix = start_digits + ''.join(map(str, digits))
        
        # Only log to console every 10 prefixes or on first/last
        if current_prefix % 10 == 0 or current_prefix == 1 or current_prefix == total_prefixes:
            logging.info(f"Processing prefix group: {prefix[:-1]}x ({current_prefix}/{total_prefixes})")
        else:
            logging.debug(f"Processing prefix: {prefix}")
        
        fetch_with_prefix(prefix, 'serial')
        fetch_with_prefix(prefix, 'periodical')
    
    logging.info("Systematic fetch complete")


def extract_record_identifier(record):
    """Extract ALMA identifier from MODS record with fallbacks"""
    try:
        # Try to get ALMA identifier
        record_info = record.find(".//{*}recordInfo/{*}recordIdentifier[@source='MH:ALMA']")
        if record_info is not None and record_info.text:
            logging.debug(f"Found ALMA identifier: {record_info.text}")
            return record_info.text
        
        # First fallback: any record identifier
        record_info = record.find(".//{*}recordInfo/{*}recordIdentifier")
        if record_info is not None and record_info.text:
            identifier = f"record_{record_info.text}"
            logging.debug(f"Using generic record identifier: {identifier}")
            return identifier
        
        # Second fallback: title
        title_info = record.find(".//{*}titleInfo/{*}title")
        if title_info is not None and title_info.text:
            identifier = sanitize_filename(title_info.text)
            logging.debug(f"Using sanitized title as identifier: {identifier}")
            return identifier
            
        logging.warning("No valid identifier found, using default")
        return "untitled_record"
    except Exception as e:
        logging.error(f"Error extracting identifier: {str(e)}")
        logging.debug("Identifier extraction error details:", exc_info=True)
        return "error_record"

def sanitize_filename(title):
    """Create a safe filename from a title"""
    safe_title = re.sub(r'[^\w\s-]', '_', title)
    safe_title = re.sub(r'[-\s]+', '_', safe_title)
    return safe_title[:100].strip('_')

def save_mods_records(xml_string, OUTPUT_DIR):
    """Save individual MODS records as separate XML files"""
    errors = []
    saved_count = 0
    skipped_count = 0
    
    try:
        root = ET.fromstring(xml_string)
        records = root.findall(".//{*}mods")
        
        if not records:
            msg = "No MODS records found in XML"
            logging.warning(msg)
            errors.append(msg)
            return 0, 0, errors
            
        for i, record in enumerate(records, 1):
            try:
                record_id = extract_record_identifier(record)
                filename = f"{record_id}.xml"
                filepath = os.path.join(OUTPUT_DIR, filename)
                
                if not OVERWRITE_FILES and os.path.exists(filepath):
                    logging.debug(f"Skipping existing file: {filename}")
                    skipped_count += 1
                    continue
                
                record_str = minidom.parseString(ET.tostring(record)).toprettyxml(indent="  ")
                record_str = '\n'.join(line for line in record_str.split('\n') if line.strip())
                
                if not record_str.startswith('<?xml'):
                    record_str = '<?xml version="1.0" encoding="UTF-8"?>\n' + record_str
                
                with open(filepath, 'w', encoding='utf-8') as f:
                    f.write(record_str)
                
                saved_count += 1
                logging.debug(f"Saved record {i}: {filename}")
                
            except Exception as e:
                error_msg = f"Error processing record {i}: {str(e)}"
                logging.error(error_msg)
                logging.debug("Record processing error details:", exc_info=True)
                errors.append(error_msg)
        
        # Summary only goes to debug
        logging.debug(f"Batch complete - Saved: {saved_count}, Skipped: {skipped_count}")
        
        return saved_count, skipped_count, errors
        
    except Exception as e:
        error_msg = f"Fatal error processing records: {str(e)}"
        logging.error(error_msg)
        logging.debug("Fatal error details:", exc_info=True)
        errors.append(error_msg)
        return saved_count, skipped_count, errors

def process_and_save_records(xml_string):
    """Process and save the records with logging"""
    saved_count, skipped_count, errors = save_mods_records(xml_string, OUTPUT_DIR)
    logging.info(f"Processed batch: {saved_count} saved, {skipped_count} skipped")
    if errors:
        logging.error(f"Errors: {errors}")
    return saved_count, skipped_count, errors

# %% [markdown]
# ## Main Analysis

# %%
# Create output directory for XML files, if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Create logs directory if it doesn't exist
os.makedirs('logs', exist_ok=True)

logging.info("Let's get started")

# Test with specific prefixes first
#test_prefixes = ['990000924', '990000925']
#for prefix in test_prefixes:
#   fetch_with_prefix(prefix, 'serial')
#   fetch_with_prefix(prefix, 'periodical')
    
# Uncomment to do a systematic fetch
systematic_fetch(start_digits='99', digit_positions=4)

logging.info("Done")
# Out:
# Let's get started
# Starting systematic fetch with 10000 prefixes...
# Processing prefix group: 99000x (1/10000)
# Found 4759 serial records for prefix 990000
# Progress: 1000/4759 records (21.0%)
# Progress: 2000/4759 records (42.0%)
# Progress: 3000/4759 records (63.0%)
# Progress: 4000/4759 records (84.1%)
# Found 1972 periodical records for prefix 990000
# Progress: 1000/1972 records (50.7%)
# Found 182 serial records for prefix 990009
# Processed batch: 182 saved, 0 skipped
# Found 166 periodical records for prefix 990009
# Processed batch: 51 saved, 115 skipped
# Found 90 serial records for prefix 990010
# Processed batch: 90 saved, 0 skipped
# Found 86 periodical records for prefix 990010
# Processed batch: 44 saved, 42 skipped
# Found 111 serial records for prefix 990011
# Processed batch: 111 saved, 0 skipped
# Found 115 periodical records for prefix 990011
# Processed batch: 47 saved, 68 skipped
# Found 336 serial records for prefix 990012
# Found 272 periodical records for prefix 990012
# Found 4439 serial records for prefix 990013
# Progress: 1000/4439 records (22.5%)
# Progress: 2000/4439 records (45.1%)
# Progress: 3000/4439 records (67.6%)
# Progress: 4000/4439 records (90.1%)
# Found 2803 periodical records for prefix 990013
# Progress: 1000/2803 records (35.7%)
# Progress: 2000/2803 records (71.4%)
# Found 2581 serial records for prefix 990014
# Progress: 1000/2581 records (38.7%)
# Progress: 2000/2581 records (77.5%)
# Found 1567 periodical records for prefix 990014
# Progress: 1000/1567 records (63.8%)
# Found 3183 serial records for prefix 990015
# Progress: 1000/3183 records (31.4%)
# Progress: 2000/3183 records (62.8%)
# Progress: 3000/3183 records (94.3%)
# Found 1894 periodical records for prefix 990015
# Progress: 1000/1894 records (52.8%)
# Found 4235 serial records for prefix 990016
# Progress: 1000/4235 records (23.6%)
# Progress: 2000/4235 records (47.2%)
# Progress: 3000/4235 records (70.8%)
# Progress: 4000/4235 records (94.5%)
# Found 2483 periodical records for prefix 990016
# Progress: 1000/2483 records (40.3%)
# Progress: 2000/2483 records (80.5%)
# Found 3546 serial records for prefix 990017
# Progress: 1000/3546 records (28.2%)
# Progress: 2000/3546 records (56.4%)
# Progress: 3000/3546 records (84.6%)
# Found 1952 periodical records for prefix 990017
# Progress: 1000/1952 records (51.2%)
# Found 3764 serial records for prefix 990018
# Progress: 1000/3764 records (26.6%)
# Progress: 2000/3764 records (53.1%)
# Progress: 3000/3764 records (79.7%)
# Found 2159 periodical records for prefix 990018
# Progress: 1000/2159 records (46.3%)
# Progress: 2000/2159 records (92.6%)
# Processing prefix group: 99001x (20/10000)
# Found 3859 serial records for prefix 990019
# Progress: 1000/3859 records (25.9%)
# Progress: 2000/3859 records (51.8%)
# Progress: 3000/3859 records (77.7%)
# Found 2189 periodical records for prefix 990019
# Progress: 1000/2189 records (45.7%)
# Progress: 2000/2189 records (91.4%)
# Found 12918 serial records for prefix 990020
# Progress: 1000/12918 records (7.7%)
# Progress: 2000/12918 records (15.5%)
# Progress: 3000/12918 records (23.2%)
# Progress: 4000/12918 records (31.0%)
# Progress: 5000/12918 records (38.7%)
# Progress: 6000/12918 records (46.4%)
# Progress: 7000/12918 records (54.2%)
# Progress: 8000/12918 records (61.9%)
# Progress: 9000/12918 records (69.7%)
# Progress: 10000/12918 records (77.4%)
# Progress: 11000/12918 records (85.2%)
# Progress: 12000/12918 records (92.9%)
# Found 6319 periodical records for prefix 990020
# Progress: 1000/6319 records (15.8%)
# Progress: 2000/6319 records (31.7%)
# Progress: 3000/6319 records (47.5%)
# Progress: 4000/6319 records (63.3%)
# Progress: 5000/6319 records (79.1%)
# Progress: 6000/6319 records (95.0%)
# Found 2698 serial records for prefix 990021
# Progress: 1000/2698 records (37.1%)
# Progress: 2000/2698 records (74.1%)
# Found 1553 periodical records for prefix 990021
# Progress: 1000/1553 records (64.4%)
# Found 2137 serial records for prefix 990022
# Progress: 1000/2137 records (46.8%)
# Progress: 2000/2137 records (93.6%)
# Found 1139 periodical records for prefix 990022
# Progress: 1000/1139 records (87.8%)
# Found 2878 serial records for prefix 990023
# Progress: 1000/2878 records (34.7%)
# Progress: 2000/2878 records (69.5%)
# Found 1590 periodical records for prefix 990023
# Progress: 1000/1590 records (62.9%)
# Found 4645 serial records for prefix 990024
# Progress: 1000/4645 records (21.5%)
# Progress: 2000/4645 records (43.1%)
# Progress: 3000/4645 records (64.6%)
# Progress: 4000/4645 records (86.1%)
# Found 2470 periodical records for prefix 990024
# Progress: 1000/2470 records (40.5%)
# Progress: 2000/2470 records (81.0%)
# Found 3582 serial records for prefix 990025
# Progress: 1000/3582 records (27.9%)
# Progress: 2000/3582 records (55.8%)
# Progress: 3000/3582 records (83.8%)
# Found 1638 periodical records for prefix 990025
# Progress: 1000/1638 records (61.1%)
# Found 4284 serial records for prefix 990026
# Progress: 1000/4284 records (23.3%)
# Progress: 2000/4284 records (46.7%)
# Progress: 3000/4284 records (70.0%)
# Progress: 4000/4284 records (93.4%)
# Found 1894 periodical records for prefix 990026
# Progress: 1000/1894 records (52.8%)
# Found 3592 serial records for prefix 990027
# Progress: 1000/3592 records (27.8%)
# Progress: 2000/3592 records (55.7%)
# Progress: 3000/3592 records (83.5%)
# Found 1742 periodical records for prefix 990027
# Progress: 1000/1742 records (57.4%)
# Found 1699 serial records for prefix 990028
# Progress: 1000/1699 records (58.9%)
# Found 935 periodical records for prefix 990028
# Processing prefix group: 99002x (30/10000)
# Found 933 serial records for prefix 990029
# Found 589 periodical records for prefix 990029
# Found 820 serial records for prefix 990030
# Found 529 periodical records for prefix 990030
# Found 1400 serial records for prefix 990031
# Progress: 1000/1400 records (71.4%)
# Found 946 periodical records for prefix 990031
# Found 1063 serial records for prefix 990032
# Progress: 1000/1063 records (94.1%)
# Found 660 periodical records for prefix 990032
# Found 1134 serial records for prefix 990033
# Progress: 1000/1134 records (88.2%)
# Found 723 periodical records for prefix 990033
# Found 1879 serial records for prefix 990034
# Progress: 1000/1879 records (53.2%)
# Found 1113 periodical records for prefix 990034
# Progress: 1000/1113 records (89.8%)
# Found 3186 serial records for prefix 990035
# Progress: 1000/3186 records (31.4%)
# Progress: 2000/3186 records (62.8%)
# Progress: 3000/3186 records (94.2%)
# Found 1390 periodical records for prefix 990035
# Progress: 1000/1390 records (71.9%)
# Found 2116 serial records for prefix 990036
# Progress: 1000/2116 records (47.3%)
# Progress: 2000/2116 records (94.5%)
# Found 1300 periodical records for prefix 990036
# Progress: 1000/1300 records (76.9%)
# Found 900 serial records for prefix 990037
# Found 561 periodical records for prefix 990037
# Found 2377 serial records for prefix 990038
# Found 1609 periodical records for prefix 990062
# Progress: 1000/1609 records (62.2%)
# Found 4086 serial records for prefix 990063
# Progress: 1000/4086 records (24.5%)
# Progress: 2000/4086 records (48.9%)
# Progress: 3000/4086 records (73.4%)
# Progress: 4000/4086 records (97.9%)
# Found 1491 periodical records for prefix 990063
# Progress: 1000/1491 records (67.1%)
# Found 3621 serial records for prefix 990064
# Progress: 1000/3621 records (27.6%)
# Progress: 2000/3621 records (55.2%)
# Progress: 3000/3621 records (82.9%)
# Found 1527 periodical records for prefix 990064
# Progress: 1000/1527 records (65.5%)
# Found 3045 serial records for prefix 990065
# Progress: 1000/3045 records (32.8%)
# Progress: 2000/3045 records (65.7%)
# Progress: 3000/3045 records (98.5%)
# Found 1365 periodical records for prefix 990065
# Progress: 1000/1365 records (73.3%)
# Found 2472 serial records for prefix 990066
# Progress: 1000/2472 records (40.5%)
# Progress: 2000/2472 records (80.9%)
# Found 1178 periodical records for prefix 990066
# Progress: 1000/1178 records (84.9%)
# Found 3492 serial records for prefix 990067
# Progress: 1000/3492 records (28.6%)
# Progress: 2000/3492 records (57.3%)
# Progress: 3000/3492 records (85.9%)
# Found 1608 periodical records for prefix 990067
# Progress: 1000/1608 records (62.2%)
# Found 2856 serial records for prefix 990068
# Progress: 1000/2856 records (35.0%)
# Progress: 2000/2856 records (70.0%)
# Found 1164 periodical records for prefix 990068
# Progress: 1000/1164 records (85.9%)
# Processing prefix group: 99006x (70/10000)
# Found 2637 serial records for prefix 990069
# Progress: 1000/2637 records (37.9%)
# Progress: 2000/2637 records (75.8%)
# Found 1392 periodical records for prefix 990069
# Progress: 1000/1392 records (71.8%)
# Found 3532 serial records for prefix 990070
# Progress: 1000/3532 records (28.3%)
# Progress: 2000/3532 records (56.6%)
# Progress: 3000/3532 records (84.9%)
# Found 1566 periodical records for prefix 990070
# Progress: 1000/1566 records (63.9%)
# Found 2737 serial records for prefix 990071
# Progress: 1000/2737 records (36.5%)
# Progress: 2000/2737 records (73.1%)
# Found 1165 periodical records for prefix 990071
# Progress: 1000/1165 records (85.8%)
# Found 9946 serial records for prefix 990072
# Progress: 1000/9946 records (10.1%)
# Progress: 2000/9946 records (20.1%)
# Progress: 3000/9946 records (30.2%)
# Progress: 4000/9946 records (40.2%)
# Progress: 5000/9946 records (50.3%)
# Progress: 6000/9946 records (60.3%)
# Progress: 7000/9946 records (70.4%)
# Progress: 8000/9946 records (80.4%)
# Progress: 9000/9946 records (90.5%)
# Found 4249 periodical records for prefix 990072
# Progress: 1000/4249 records (23.5%)
# Progress: 2000/4249 records (47.1%)
# Progress: 3000/4249 records (70.6%)
# Progress: 4000/4249 records (94.1%)
# Found 4138 serial records for prefix 990073
# Progress: 1000/4138 records (24.2%)
# Progress: 2000/4138 records (48.3%)
# Progress: 3000/4138 records (72.5%)
# Progress: 4000/4138 records (96.7%)
# Found 1807 periodical records for prefix 990073
# Progress: 1000/1807 records (55.3%)
# Found 3535 serial records for prefix 990074
# Progress: 1000/3535 records (28.3%)
# Progress: 2000/3535 records (56.6%)
# Found 1576 serial records for prefix 990096
# Progress: 1000/1576 records (63.5%)
# Found 1432 periodical records for prefix 990096
# Progress: 1000/1432 records (69.8%)
# Found 3087 serial records for prefix 990097
# Progress: 1000/3087 records (32.4%)
# Progress: 2000/3087 records (64.8%)
# Progress: 3000/3087 records (97.2%)
# Found 2181 periodical records for prefix 990097
# Progress: 1000/2181 records (45.9%)
# Progress: 2000/2181 records (91.7%)
# Found 2235 serial records for prefix 990098
# Progress: 1000/2235 records (44.7%)
# Progress: 2000/2235 records (89.5%)
# Found 1520 periodical records for prefix 990098
# Progress: 1000/1520 records (65.8%)
# Processing prefix group: 99009x (100/10000)
# Found 3078 serial records for prefix 990099
# Progress: 1000/3078 records (32.5%)
# Progress: 2000/3078 records (65.0%)
# Progress: 3000/3078 records (97.5%)
# Found 2541 periodical records for prefix 990099
# Progress: 1000/2541 records (39.4%)
# Progress: 2000/2541 records (78.7%)
# Found 1264 serial records for prefix 990100
# Progress: 1000/1264 records (79.1%)
# Found 1011 periodical records for prefix 990100
# Progress: 1000/1011 records (98.9%)
# Found 2292 serial records for prefix 990101
# Progress: 1000/2292 records (43.6%)
# Progress: 2000/2292 records (87.3%)
# Found 1780 periodical records for prefix 990101
# Progress: 1000/1780 records (56.2%)
# Found 3272 serial records for prefix 990102
# Progress: 1000/3272 records (30.6%)
# Progress: 2000/3272 records (61.1%)
# Progress: 3000/3272 records (91.7%)
# Found 2231 periodical records for prefix 990102
# Progress: 1000/2231 records (44.8%)
# Progress: 2000/2231 records (89.6%)
# Found 489 serial records for prefix 990103
# Found 301 periodical records for prefix 990103
# Found 491 serial records for prefix 990104
# Found 252 periodical records for prefix 990104
# Found 2679 serial records for prefix 990105
# Progress: 1000/2679 records (37.3%)
# Progress: 2000/2679 records (74.7%)
# Found 1888 periodical records for prefix 990105
# Progress: 1000/1888 records (53.0%)
# Found 138 serial records for prefix 990106
# Processed batch: 138 saved, 0 skipped
# Found 105 periodical records for prefix 990106
# Processed batch: 12 saved, 93 skipped
# Found 235 serial records for prefix 990107
# Processed batch: 235 saved, 0 skipped
# Found 163 periodical records for prefix 990107
# Processed batch: 12 saved, 151 skipped
# Found 778 serial records for prefix 990108
# Found 365 periodical records for prefix 990108
# Processing prefix group: 99010x (110/10000)
# Found 250 serial records for prefix 990109
# Processed batch: 250 saved, 0 skipped
# Found 198 periodical records for prefix 990109
# Processed batch: 27 saved, 171 skipped
# Found 174 serial records for prefix 990110
# Processed batch: 174 saved, 0 skipped
# Found 105 periodical records for prefix 990110
# Processed batch: 1 saved, 104 skipped
# Found 579 serial records for prefix 990111
# Found 460 periodical records for prefix 990111
# Found 380 serial records for prefix 990112
# Found 304 periodical records for prefix 990112
# Found 3101 serial records for prefix 990113
# Progress: 1000/3101 records (32.2%)
# Progress: 2000/3101 records (64.5%)
# Progress: 3000/3101 records (96.7%)
# Found 2257 periodical records for prefix 990113
# Progress: 1000/2257 records (44.3%)
# Progress: 2000/2257 records (88.6%)
# Found 2720 serial records for prefix 990114
# Progress: 1000/2720 records (36.8%)
# Progress: 2000/2720 records (73.5%)
# Found 2022 periodical records for prefix 990114
# Progress: 1000/2022 records (49.5%)
# Progress: 2000/2022 records (98.9%)
# Found 2909 serial records for prefix 990115
# Progress: 1000/2909 records (34.4%)
# Progress: 2000/2909 records (68.8%)
# Found 1985 periodical records for prefix 990115
# Progress: 1000/1985 records (50.4%)
# Found 10 serial records for prefix 990116
# Processed batch: 10 saved, 0 skipped
# Found 5 periodical records for prefix 990116
# Processed batch: 0 saved, 5 skipped
# Found 1780 serial records for prefix 990117
# Progress: 1000/1780 records (56.2%)
# Found 1392 periodical records for prefix 990117
# Progress: 1000/1392 records (71.8%)
# Found 1624 serial records for prefix 990118
# Progress: 1000/1624 records (61.6%)
# Found 1264 periodical records for prefix 990118
# Progress: 1000/1264 records (79.1%)
# Processing prefix group: 99011x (120/10000)
# Found 2258 serial records for prefix 990119
# Progress: 1000/2258 records (44.3%)
# Progress: 2000/2258 records (88.6%)
# Found 1815 periodical records for prefix 990119
# Progress: 1000/1815 records (55.1%)
# Found 2102 serial records for prefix 990120
# Progress: 1000/2102 records (47.6%)
# Progress: 2000/2102 records (95.1%)
# Found 1594 periodical records for prefix 990120
# Progress: 1000/1594 records (62.7%)
# Found 1998 serial records for prefix 990121
# Progress: 1000/1998 records (50.1%)
# Found 1630 periodical records for prefix 990121
# Progress: 1000/1630 records (61.3%)
# Found 1708 serial records for prefix 990122
# Progress: 1000/1708 records (58.5%)
# Found 1496 periodical records for prefix 990122
# Progress: 1000/1496 records (66.8%)
# Found 1419 serial records for prefix 990123
# Progress: 1000/1419 records (70.5%)
# Found 1183 periodical records for prefix 990123
# Progress: 1000/1183 records (84.5%)
# Found 2 serial records for prefix 990124
# Processed batch: 2 saved, 0 skipped
# Found 327 periodical records for prefix 990124
# Found 1968 serial records for prefix 990125
# Progress: 1000/1968 records (50.8%)
# Found 1548 periodical records for prefix 990125
# Progress: 1000/1548 records (64.6%)
# Found 1889 serial records for prefix 990126
# Progress: 1000/1889 records (52.9%)
# Found 1540 periodical records for prefix 990126
# Progress: 1000/1540 records (64.9%)
# Found 2246 serial records for prefix 990127
# Progress: 1000/2246 records (44.5%)
# Progress: 2000/2246 records (89.0%)
# Found 1740 periodical records for prefix 990127
# Progress: 1000/1740 records (57.5%)
# Found 1426 serial records for prefix 990128
# Progress: 1000/1426 records (70.1%)
# Found 1074 periodical records for prefix 990128
# Progress: 1000/1074 records (93.1%)
# Processing prefix group: 99012x (130/10000)
# Found 1298 serial records for prefix 990129
# Progress: 1000/1298 records (77.0%)
# Found 1042 periodical records for prefix 990129
# Progress: 1000/1042 records (96.0%)
# Found 895 serial records for prefix 990130
# Found 629 periodical records for prefix 990130
# Found 2004 serial records for prefix 990131
# Progress: 1000/2004 records (49.9%)
# Progress: 2000/2004 records (99.8%)
# Found 1195 periodical records for prefix 990131
# Progress: 1000/1195 records (83.7%)
# Found 1660 serial records for prefix 990132
# Progress: 1000/1660 records (60.2%)
# Found 476 periodical records for prefix 990132
# Found 1461 serial records for prefix 990133
# Progress: 1000/1461 records (68.4%)
# Found 1151 periodical records for prefix 990133
# Progress: 1000/1151 records (86.9%)
# Found 751 serial records for prefix 990134
# Found 556 periodical records for prefix 990134
# Found 565 serial records for prefix 990135
# Found 396 periodical records for prefix 990135
# Found 1737 serial records for prefix 990136
# Progress: 1000/1737 records (57.6%)
# Found 1425 periodical records for prefix 990136
# Progress: 1000/1425 records (70.2%)
# Found 2119 serial records for prefix 990137
# Progress: 1000/2119 records (47.2%)
# Progress: 2000/2119 records (94.4%)
# Found 1824 periodical records for prefix 990137
# Progress: 1000/1824 records (54.8%)
# Found 1294 serial records for prefix 990138
# Progress: 1000/1294 records (77.3%)
# Found 1059 periodical records for prefix 990138
# Progress: 1000/1059 records (94.4%)
# Processing prefix group: 99013x (140/10000)
# Found 1785 serial records for prefix 990139
# Progress: 1000/1785 records (56.0%)
# Found 1464 periodical records for prefix 990139
# Progress: 1000/1464 records (68.3%)
# Found 1208 serial records for prefix 990140
# Progress: 1000/1208 records (82.8%)
# Found 934 periodical records for prefix 990140
# Found 1430 serial records for prefix 990141
# Progress: 1000/1430 records (69.9%)
# Found 1138 periodical records for prefix 990141
# Progress: 1000/1138 records (87.9%)
# Found 1424 serial records for prefix 990142
# Progress: 1000/1424 records (70.2%)
# Found 1213 periodical records for prefix 990142
# Progress: 1000/1213 records (82.4%)
# Found 1446 serial records for prefix 990143
# Progress: 1000/1446 records (69.2%)
# Found 1209 periodical records for prefix 990143
# Progress: 1000/1209 records (82.7%)
# Found 1773 serial records for prefix 990144
# Progress: 1000/1773 records (56.4%)
# Found 1571 periodical records for prefix 990144
# Progress: 1000/1571 records (63.7%)
# Found 1894 serial records for prefix 990145
# Progress: 1000/1894 records (52.8%)
# Found 1509 periodical records for prefix 990145
# Progress: 1000/1509 records (66.3%)
# Found 2181 serial records for prefix 990146
# Progress: 1000/2181 records (45.9%)
# Progress: 2000/2181 records (91.7%)
# Found 1685 periodical records for prefix 990146
# Progress: 1000/1685 records (59.3%)
# Found 2475 serial records for prefix 990147
# Progress: 1000/2475 records (40.4%)
# Progress: 2000/2475 records (80.8%)
# Found 2035 periodical records for prefix 990147
# Progress: 1000/2035 records (49.1%)
# Progress: 2000/2035 records (98.3%)
# Found 2318 serial records for prefix 990148
# Progress: 1000/2318 records (43.1%)
# Progress: 2000/2318 records (86.3%)
# Found 2049 periodical records for prefix 990148
# Progress: 1000/2049 records (48.8%)
# Progress: 2000/2049 records (97.6%)
# Processing prefix group: 99014x (150/10000)
# Found 1264 serial records for prefix 990149
# Progress: 1000/1264 records (79.1%)
# Found 1071 periodical records for prefix 990149
# Progress: 1000/1071 records (93.4%)
# Found 2056 serial records for prefix 990150
# Progress: 1000/2056 records (48.6%)
# Progress: 2000/2056 records (97.3%)
# Found 1879 periodical records for prefix 990150
# Progress: 1000/1879 records (53.2%)
# Found 1023 serial records for prefix 990151
# Progress: 1000/1023 records (97.8%)
# Found 832 periodical records for prefix 990151
# Found 2438 serial records for prefix 990152
# Progress: 1000/2438 records (41.0%)
# Progress: 2000/2438 records (82.0%)
# Found 2115 periodical records for prefix 990152
# Progress: 1000/2115 records (47.3%)
# Progress: 2000/2115 records (94.6%)
# Found 574 serial records for prefix 990153
# Found 458 periodical records for prefix 990153
# Processing prefix group: 99015x (160/10000)
# Processing prefix group: 99016x (170/10000)
# Processing prefix group: 99017x (180/10000)
# Processing prefix group: 99018x (190/10000)
# Processing prefix group: 99019x (200/10000)
# Processing prefix group: 99020x (210/10000)
# Processing prefix group: 99021x (220/10000)
# Processing prefix group: 99022x (230/10000)
# Processing prefix group: 99023x (240/10000)
# Processing prefix group: 99024x (250/10000)
# Processing prefix group: 99025x (260/10000)
# Processing prefix group: 99026x (270/10000)
# Processing prefix group: 99027x (280/10000)
# Processing prefix group: 99028x (290/10000)
# Processing prefix group: 99029x (300/10000)
# Processing prefix group: 99030x (310/10000)
# Processing prefix group: 99031x (320/10000)
# Processing prefix group: 99032x (330/10000)
# Processing prefix group: 99033x (340/10000)
# Processing prefix group: 99034x (350/10000)
# Processing prefix group: 99035x (360/10000)
# Processing prefix group: 99036x (370/10000)
# Processing prefix group: 99037x (380/10000)
# Processing prefix group: 99038x (390/10000)
# Processing prefix group: 99039x (400/10000)
# Processing prefix group: 99040x (410/10000)
# Processing prefix group: 99041x (420/10000)
# Processing prefix group: 99042x (430/10000)
# Processing prefix group: 99043x (440/10000)
# Processing prefix group: 99044x (450/10000)
# Processing prefix group: 99045x (460/10000)
# Processing prefix group: 99046x (470/10000)
# Processing prefix group: 99047x (480/10000)
# Processing prefix group: 99048x (490/10000)
# Processing prefix group: 99049x (500/10000)
# Processing prefix group: 99050x (510/10000)
# Processing prefix group: 99051x (520/10000)
# Processing prefix group: 99052x (530/10000)
# Processing prefix group: 99053x (540/10000)
# Processing prefix group: 99054x (550/10000)
# Processing prefix group: 99055x (560/10000)
# Processing prefix group: 99056x (570/10000)
# Processing prefix group: 99057x (580/10000)
# Processing prefix group: 99058x (590/10000)
# Processing prefix group: 99059x (600/10000)
# Processing prefix group: 99060x (610/10000)
# Processing prefix group: 99061x (620/10000)
# Processing prefix group: 99062x (630/10000)
# Processing prefix group: 99063x (640/10000)
# Processing prefix group: 99064x (650/10000)
# Processing prefix group: 99065x (660/10000)
# Processing prefix group: 99066x (670/10000)
# Processing prefix group: 99067x (680/10000)
# Processing prefix group: 99068x (690/10000)
# Processing prefix group: 99069x (700/10000)
# Processing prefix group: 99070x (710/10000)
# Processing prefix group: 99071x (720/10000)
# Processing prefix group: 99072x (730/10000)
# Processing prefix group: 99073x (740/10000)
# Processing prefix group: 99074x (750/10000)
# Processing prefix group: 99075x (760/10000)
# Processing prefix group: 99076x (770/10000)
# Processing prefix group: 99077x (780/10000)
# Processing prefix group: 99078x (790/10000)
# Processing prefix group: 99079x (800/10000)
# Processing prefix group: 99080x (810/10000)
# Processing prefix group: 99081x (820/10000)
# Processing prefix group: 99082x (830/10000)
# Processing prefix group: 99083x (840/10000)
# Processing prefix group: 99084x (850/10000)
# Processing prefix group: 99085x (860/10000)
# Processing prefix group: 99086x (870/10000)
# Processing prefix group: 99087x (880/10000)
# Processing prefix group: 99088x (890/10000)
# Processing prefix group: 99089x (900/10000)
# Processing prefix group: 99090x (910/10000)
# Processing prefix group: 99091x (920/10000)
# Processing prefix group: 99092x (930/10000)
# Processing prefix group: 99093x (940/10000)
# Processing prefix group: 99094x (950/10000)
# Processing prefix group: 99095x (960/10000)
# Processing prefix group: 99096x (970/10000)
# Processing prefix group: 99097x (980/10000)
# Processing prefix group: 99098x (990/10000)
# Processing prefix group: 99099x (1000/10000)
# Processing prefix group: 99100x (1010/10000)
# Processing prefix group: 99101x (1020/10000)
# Processing prefix group: 99102x (1030/10000)
# Processing prefix group: 99103x (1040/10000)
# Processing prefix group: 99104x (1050/10000)
# Processing prefix group: 99105x (1060/10000)
# Processing prefix group: 99106x (1070/10000)
# Processing prefix group: 99107x (1080/10000)
# Processing prefix group: 99108x (1090/10000)
# Processing prefix group: 99109x (1100/10000)
# Processing prefix group: 99110x (1110/10000)
# Processing prefix group: 99111x (1120/10000)
# Processing prefix group: 99112x (1130/10000)
# Processing prefix group: 99113x (1140/10000)
# Processing prefix group: 99114x (1150/10000)
# Processing prefix group: 99115x (1160/10000)
# Processing prefix group: 99116x (1170/10000)
# Processing prefix group: 99117x (1180/10000)
# Processing prefix group: 99118x (1190/10000)
# Processing prefix group: 99119x (1200/10000)
# Processing prefix group: 99120x (1210/10000)
# Processing prefix group: 99121x (1220/10000)
# Processing prefix group: 99122x (1230/10000)
# Processing prefix group: 99123x (1240/10000)
# Processing prefix group: 99124x (1250/10000)
# Processing prefix group: 99125x (1260/10000)
# Processing prefix group: 99126x (1270/10000)
# Processing prefix group: 99127x (1280/10000)
# Processing prefix group: 99128x (1290/10000)
# Processing prefix group: 99129x (1300/10000)
# Processing prefix group: 99130x (1310/10000)
# Processing prefix group: 99131x (1320/10000)
# Processing prefix group: 99132x (1330/10000)
# Processing prefix group: 99133x (1340/10000)
# Processing prefix group: 99134x (1350/10000)
# Processing prefix group: 99135x (1360/10000)
# Processing prefix group: 99136x (1370/10000)
# Processing prefix group: 99137x (1380/10000)
# Processing prefix group: 99138x (1390/10000)
# Processing prefix group: 99139x (1400/10000)
# Processing prefix group: 99140x (1410/10000)
# Processing prefix group: 99141x (1420/10000)
# Processing prefix group: 99142x (1430/10000)
# Processing prefix group: 99143x (1440/10000)
# Processing prefix group: 99144x (1450/10000)
# Processing prefix group: 99145x (1460/10000)
# Processing prefix group: 99146x (1470/10000)
# Processing prefix group: 99147x (1480/10000)
# Processing prefix group: 99148x (1490/10000)
# Processing prefix group: 99149x (1500/10000)
# Processing prefix group: 99150x (1510/10000)
# Processing prefix group: 99151x (1520/10000)
# Processing prefix group: 99152x (1530/10000)
# Found 96825 serial records for prefix 991535
# Progress: 1000/96825 records (1.0%)
# Progress: 2000/96825 records (2.1%)
# Progress: 3000/96825 records (3.1%)
# Progress: 4000/96825 records (4.1%)
# Progress: 5000/96825 records (5.2%)
# Progress: 6000/96825 records (6.2%)
# Progress: 7000/96825 records (7.2%)
# Progress: 85000/96825 records (87.8%)
# Progress: 86000/96825 records (88.8%)
# Progress: 87000/96825 records (89.9%)
# Progress: 88000/96825 records (90.9%)
# Progress: 89000/96825 records (91.9%)
# Progress: 90000/96825 records (93.0%)
# Progress: 91000/96825 records (94.0%)
# Progress: 92000/96825 records (95.0%)
# Progress: 93000/96825 records (96.0%)
# Progress: 94000/96825 records (97.1%)
# Progress: 95000/96825 records (98.1%)
# Progress: 96000/96825 records (99.1%)
# Found 52643 periodical records for prefix 991535
# ...
# Processing prefix group: 99646x (6470/10000)
# Processing prefix group: 99647x (6480/10000)
# Processing prefix group: 99648x (6490/10000)
# Processing prefix group: 99649x (6500/10000)
# Processing prefix group: 99650x (6510/10000)
# Processing prefix group: 99651x (6520/10000)
# Processing prefix group: 99652x (6530/10000)
# Processing prefix group: 99653x (6540/10000)
# Processing prefix group: 99654x (6550/10000)
# Processing prefix group: 99655x (6560/10000)
# Processing prefix group: 99656x (6570/10000)
# Processing prefix group: 99657x (6580/10000)
# Processing prefix group: 99658x (6590/10000)
# Processing prefix group: 99659x (6600/10000)
# Processing prefix group: 99660x (6610/10000)
# Processing prefix group: 99661x (6620/10000)
# Processing prefix group: 99662x (6630/10000)
# Processing prefix group: 99663x (6640/10000)
# Processing prefix group: 99664x (6650/10000)
# Processing prefix group: 99665x (6660/10000)
# Processing prefix group: 99666x (6670/10000)
# Processing prefix group: 99667x (6680/10000)
# Processing prefix group: 99668x (6690/10000)
# Processing prefix group: 99669x (6700/10000)
# Processing prefix group: 99670x (6710/10000)
# Processing prefix group: 99671x (6720/10000)
# Processing prefix group: 99672x (6730/10000)
# Processing prefix group: 99673x (6740/10000)
# Processing prefix group: 99674x (6750/10000)
# Processing prefix group: 99675x (6760/10000)
# Processing prefix group: 99676x (6770/10000)
# Processing prefix group: 99677x (6780/10000)
# Processing prefix group: 99678x (6790/10000)
# Processing prefix group: 99679x (6800/10000)
# Processing prefix group: 99680x (6810/10000)
# Processing prefix group: 99681x (6820/10000)
# Processing prefix group: 99682x (6830/10000)
# Processing prefix group: 99683x (6840/10000)
# Processing prefix group: 99684x (6850/10000)
# Processing prefix group: 99685x (6860/10000)
# Processing prefix group: 99686x (6870/10000)
# Processing prefix group: 99687x (6880/10000)
# Processing prefix group: 99688x (6890/10000)
# Processing prefix group: 99689x (6900/10000)
# Processing prefix group: 99690x (6910/10000)
# Processing prefix group: 99691x (6920/10000)
# Processing prefix group: 99692x (6930/10000)
# Processing prefix group: 99693x (6940/10000)
# Processing prefix group: 99694x (6950/10000)
# Processing prefix group: 99695x (6960/10000)
# Processing prefix group: 99696x (6970/10000)
# Processing prefix group: 99697x (6980/10000)
# Processing prefix group: 99698x (6990/10000)
# Processing prefix group: 99699x (7000/10000)
# Processing prefix group: 99700x (7010/10000)
# Processing prefix group: 99701x (7020/10000)
# Processing prefix group: 99702x (7030/10000)
# Processing prefix group: 99703x (7040/10000)
# Processing prefix group: 99704x (7050/10000)
# Processing prefix group: 99705x (7060/10000)
# Processing prefix group: 99706x (7070/10000)
# Processing prefix group: 99707x (7080/10000)
# Processing prefix group: 99708x (7090/10000)
# Processing prefix group: 99709x (7100/10000)
# Processing prefix group: 99710x (7110/10000)
# Processing prefix group: 99711x (7120/10000)
# Processing prefix group: 99712x (7130/10000)
# Processing prefix group: 99713x (7140/10000)
# Processing prefix group: 99714x (7150/10000)
# Processing prefix group: 99715x (7160/10000)
# Processing prefix group: 99716x (7170/10000)
# Processing prefix group: 99717x (7180/10000)
# Processing prefix group: 99718x (7190/10000)
# Processing prefix group: 99719x (7200/10000)
# Processing prefix group: 99720x (7210/10000)
# Processing prefix group: 99721x (7220/10000)
# Processing prefix group: 99722x (7230/10000)
# Processing prefix group: 99723x (7240/10000)
# Processing prefix group: 99724x (7250/10000)
# Processing prefix group: 99725x (7260/10000)
# Processing prefix group: 99726x (7270/10000)
# Processing prefix group: 99727x (7280/10000)
# Processing prefix group: 99728x (7290/10000)
# Processing prefix group: 99729x (7300/10000)
# Processing prefix group: 99730x (7310/10000)
# Processing prefix group: 99731x (7320/10000)
# Processing prefix group: 99732x (7330/10000)
# Processing prefix group: 99733x (7340/10000)
# Processing prefix group: 99734x (7350/10000)
# Processing prefix group: 99735x (7360/10000)
# Processing prefix group: 99736x (7370/10000)
# Processing prefix group: 99737x (7380/10000)
# Processing prefix group: 99738x (7390/10000)
# Processing prefix group: 99739x (7400/10000)
# Processing prefix group: 99740x (7410/10000)
# Processing prefix group: 99741x (7420/10000)
# Processing prefix group: 99742x (7430/10000)
# Processing prefix group: 99743x (7440/10000)
# Processing prefix group: 99744x (7450/10000)
# Processing prefix group: 99745x (7460/10000)
# Processing prefix group: 99746x (7470/10000)
# Processing prefix group: 99747x (7480/10000)
# Processing prefix group: 99748x (7490/10000)
# Processing prefix group: 99749x (7500/10000)
# Processing prefix group: 99750x (7510/10000)
# Processing prefix group: 99751x (7520/10000)
# Processing prefix group: 99752x (7530/10000)
# Processing prefix group: 99753x (7540/10000)
# Processing prefix group: 99754x (7550/10000)
# Processing prefix group: 99755x (7560/10000)
# Processing prefix group: 99756x (7570/10000)
# Processing prefix group: 99757x (7580/10000)
# Processing prefix group: 99758x (7590/10000)
# Processing prefix group: 99759x (7600/10000)
# Processing prefix group: 99760x (7610/10000)
# Processing prefix group: 99761x (7620/10000)
# Processing prefix group: 99762x (7630/10000)
# Processing prefix group: 99763x (7640/10000)
# Processing prefix group: 99764x (7650/10000)
# Processing prefix group: 99765x (7660/10000)
# Processing prefix group: 99766x (7670/10000)
# Processing prefix group: 99767x (7680/10000)
# Processing prefix group: 99768x (7690/10000)
# Processing prefix group: 99769x (7700/10000)
# Processing prefix group: 99770x (7710/10000)
# Processing prefix group: 99771x (7720/10000)
# Processing prefix group: 99772x (7730/10000)
# Processing prefix group: 99773x (7740/10000)
# Processing prefix group: 99774x (7750/10000)
# Processing prefix group: 99775x (7760/10000)
# Processing prefix group: 99776x (7770/10000)
# Processing prefix group: 99777x (7780/10000)
# Processing prefix group: 99778x (7790/10000)
# Processing prefix group: 99779x (7800/10000)
# Processing prefix group: 99780x (7810/10000)
# Processing prefix group: 99781x (7820/10000)
# Processing prefix group: 99782x (7830/10000)
# Processing prefix group: 99783x (7840/10000)
# Processing prefix group: 99784x (7850/10000)
# Processing prefix group: 99785x (7860/10000)
# Processing prefix group: 99786x (7870/10000)
# Processing prefix group: 99787x (7880/10000)
# Processing prefix group: 99788x (7890/10000)
# Processing prefix group: 99789x (7900/10000)
# Processing prefix group: 99790x (7910/10000)
# Processing prefix group: 99791x (7920/10000)
# Processing prefix group: 99792x (7930/10000)
# Processing prefix group: 99793x (7940/10000)
# Processing prefix group: 99794x (7950/10000)
# Processing prefix group: 99795x (7960/10000)
# Processing prefix group: 99796x (7970/10000)
# Processing prefix group: 99797x (7980/10000)
# Processing prefix group: 99798x (7990/10000)
# Processing prefix group: 99799x (8000/10000)
# Processing prefix group: 99800x (8010/10000)
# Processing prefix group: 99801x (8020/10000)
# Processing prefix group: 99802x (8030/10000)
# Processing prefix group: 99803x (8040/10000)
# Processing prefix group: 99804x (8050/10000)
# Processing prefix group: 99805x (8060/10000)
# Processing prefix group: 99806x (8070/10000)
# Processing prefix group: 99807x (8080/10000)
# Processing prefix group: 99808x (8090/10000)
# Processing prefix group: 99809x (8100/10000)
# Processing prefix group: 99810x (8110/10000)
# Processing prefix group: 99811x (8120/10000)
# Processing prefix group: 99812x (8130/10000)
# Processing prefix group: 99813x (8140/10000)
# Processing prefix group: 99814x (8150/10000)
# Processing prefix group: 99815x (8160/10000)
# Processing prefix group: 99816x (8170/10000)
# Processing prefix group: 99817x (8180/10000)
# Processing prefix group: 99818x (8190/10000)
# Processing prefix group: 99819x (8200/10000)
# Processing prefix group: 99820x (8210/10000)
# Processing prefix group: 99821x (8220/10000)
# Processing prefix group: 99822x (8230/10000)
# Processing prefix group: 99823x (8240/10000)
# Processing prefix group: 99824x (8250/10000)
# Processing prefix group: 99825x (8260/10000)
# Processing prefix group: 99826x (8270/10000)
# Processing prefix group: 99827x (8280/10000)
# Processing prefix group: 99828x (8290/10000)
# Processing prefix group: 99829x (8300/10000)
# Processing prefix group: 99830x (8310/10000)
# Processing prefix group: 99831x (8320/10000)
# Processing prefix group: 99832x (8330/10000)
# Processing prefix group: 99833x (8340/10000)
# Processing prefix group: 99834x (8350/10000)
# Processing prefix group: 99835x (8360/10000)
# Processing prefix group: 99836x (8370/10000)
# Processing prefix group: 99837x (8380/10000)
# Processing prefix group: 99838x (8390/10000)
# Processing prefix group: 99839x (8400/10000)
# Processing prefix group: 99840x (8410/10000)
# Processing prefix group: 99841x (8420/10000)
# Processing prefix group: 99842x (8430/10000)
# Processing prefix group: 99843x (8440/10000)
# Processing prefix group: 99844x (8450/10000)
# Processing prefix group: 99845x (8460/10000)
# Processing prefix group: 99846x (8470/10000)
# Processing prefix group: 99847x (8480/10000)
# Processing prefix group: 99848x (8490/10000)
# Processing prefix group: 99849x (8500/10000)
# Processing prefix group: 99850x (8510/10000)
# Processing prefix group: 99851x (8520/10000)
# Processing prefix group: 99852x (8530/10000)
# Processing prefix group: 99853x (8540/10000)
# Processing prefix group: 99854x (8550/10000)
# Processing prefix group: 99855x (8560/10000)
# Processing prefix group: 99856x (8570/10000)
# Processing prefix group: 99857x (8580/10000)
# Processing prefix group: 99858x (8590/10000)
# Processing prefix group: 99859x (8600/10000)
# Processing prefix group: 99860x (8610/10000)
# Processing prefix group: 99861x (8620/10000)
# Processing prefix group: 99862x (8630/10000)
# Processing prefix group: 99863x (8640/10000)
# Processing prefix group: 99864x (8650/10000)
# Processing prefix group: 99865x (8660/10000)
# Processing prefix group: 99866x (8670/10000)
# Processing prefix group: 99867x (8680/10000)
# Processing prefix group: 99868x (8690/10000)
# Processing prefix group: 99869x (8700/10000)
# Processing prefix group: 99870x (8710/10000)
# Processing prefix group: 99871x (8720/10000)
# Processing prefix group: 99872x (8730/10000)
# Processing prefix group: 99873x (8740/10000)
# Processing prefix group: 99874x (8750/10000)
# Processing prefix group: 99875x (8760/10000)
# Processing prefix group: 99876x (8770/10000)
# Processing prefix group: 99877x (8780/10000)
# Processing prefix group: 99878x (8790/10000)
# Processing prefix group: 99879x (8800/10000)
# Processing prefix group: 99880x (8810/10000)
# Processing prefix group: 99881x (8820/10000)
# Processing prefix group: 99882x (8830/10000)
# Processing prefix group: 99883x (8840/10000)
# Processing prefix group: 99884x (8850/10000)
# Processing prefix group: 99885x (8860/10000)
# Processing prefix group: 99886x (8870/10000)
# Processing prefix group: 99887x (8880/10000)
# Processing prefix group: 99888x (8890/10000)
# Processing prefix group: 99889x (8900/10000)
# Processing prefix group: 99890x (8910/10000)
# Processing prefix group: 99891x (8920/10000)
# Processing prefix group: 99892x (8930/10000)
# Processing prefix group: 99893x (8940/10000)
# Processing prefix group: 99894x (8950/10000)
# Processing prefix group: 99895x (8960/10000)
# Processing prefix group: 99896x (8970/10000)
# Processing prefix group: 99897x (8980/10000)
# Processing prefix group: 99898x (8990/10000)
# Processing prefix group: 99899x (9000/10000)
# Processing prefix group: 99900x (9010/10000)
# Processing prefix group: 99901x (9020/10000)
# Processing prefix group: 99902x (9030/10000)
# Processing prefix group: 99903x (9040/10000)
# Processing prefix group: 99904x (9050/10000)
# Processing prefix group: 99905x (9060/10000)
# Processing prefix group: 99906x (9070/10000)
# Processing prefix group: 99907x (9080/10000)
# Processing prefix group: 99908x (9090/10000)
# Processing prefix group: 99909x (9100/10000)
# Processing prefix group: 99910x (9110/10000)
# Processing prefix group: 99911x (9120/10000)
# Processing prefix group: 99912x (9130/10000)
# Processing prefix group: 99913x (9140/10000)
# Processing prefix group: 99914x (9150/10000)
# Processing prefix group: 99915x (9160/10000)
# Processing prefix group: 99916x (9170/10000)
# Processing prefix group: 99917x (9180/10000)
# Processing prefix group: 99918x (9190/10000)
# Processing prefix group: 99919x (9200/10000)
# Processing prefix group: 99920x (9210/10000)
# Processing prefix group: 99921x (9220/10000)
# Processing prefix group: 99922x (9230/10000)
# Processing prefix group: 99923x (9240/10000)
# Processing prefix group: 99924x (9250/10000)
# Processing prefix group: 99925x (9260/10000)
# Processing prefix group: 99926x (9270/10000)
# Processing prefix group: 99927x (9280/10000)
# Processing prefix group: 99928x (9290/10000)
# Processing prefix group: 99929x (9300/10000)
# Processing prefix group: 99930x (9310/10000)
# Processing prefix group: 99931x (9320/10000)
# Processing prefix group: 99932x (9330/10000)
# Processing prefix group: 99933x (9340/10000)
# Processing prefix group: 99934x (9350/10000)
# Processing prefix group: 99935x (9360/10000)
# Processing prefix group: 99936x (9370/10000)
# Processing prefix group: 99937x (9380/10000)
# Processing prefix group: 99938x (9390/10000)
# Processing prefix group: 99939x (9400/10000)
# Processing prefix group: 99940x (9410/10000)
# Processing prefix group: 99941x (9420/10000)
# Processing prefix group: 99942x (9430/10000)
# Processing prefix group: 99943x (9440/10000)
# Processing prefix group: 99944x (9450/10000)
# Processing prefix group: 99945x (9460/10000)
# Processing prefix group: 99946x (9470/10000)
# Processing prefix group: 99947x (9480/10000)
# Processing prefix group: 99948x (9490/10000)
# Processing prefix group: 99949x (9500/10000)
# Processing prefix group: 99950x (9510/10000)
# Processing prefix group: 99951x (9520/10000)
# Processing prefix group: 99952x (9530/10000)
# Processing prefix group: 99953x (9540/10000)
# Processing prefix group: 99954x (9550/10000)
# Processing prefix group: 99955x (9560/10000)
# Processing prefix group: 99956x (9570/10000)
# Processing prefix group: 99957x (9580/10000)
# Processing prefix group: 99958x (9590/10000)
# Processing prefix group: 99959x (9600/10000)
# Processing prefix group: 99960x (9610/10000)
# Processing prefix group: 99961x (9620/10000)
# Processing prefix group: 99962x (9630/10000)
# Processing prefix group: 99963x (9640/10000)
# Processing prefix group: 99964x (9650/10000)
# Processing prefix group: 99965x (9660/10000)
# Processing prefix group: 99966x (9670/10000)
# Processing prefix group: 99967x (9680/10000)
# Processing prefix group: 99968x (9690/10000)
# Processing prefix group: 99969x (9700/10000)
# Processing prefix group: 99970x (9710/10000)
# Processing prefix group: 99971x (9720/10000)
# Processing prefix group: 99972x (9730/10000)
# Processing prefix group: 99973x (9740/10000)
# Processing prefix group: 99974x (9750/10000)
# Processing prefix group: 99975x (9760/10000)
# Processing prefix group: 99976x (9770/10000)
# Processing prefix group: 99977x (9780/10000)
# Processing prefix group: 99978x (9790/10000)
# Processing prefix group: 99979x (9800/10000)
# Processing prefix group: 99980x (9810/10000)
# Processing prefix group: 99981x (9820/10000)
# Processing prefix group: 99982x (9830/10000)
# Processing prefix group: 99983x (9840/10000)
# Processing prefix group: 99984x (9850/10000)
# Processing prefix group: 99985x (9860/10000)
# Processing prefix group: 99986x (9870/10000)
# Processing prefix group: 99987x (9880/10000)
# Processing prefix group: 99988x (9890/10000)
# Processing prefix group: 99989x (9900/10000)
# Processing prefix group: 99990x (9910/10000)
# Processing prefix group: 99991x (9920/10000)
# Processing prefix group: 99992x (9930/10000)
# Processing prefix group: 99993x (9940/10000)
# Processing prefix group: 99994x (9950/10000)
# Processing prefix group: 99995x (9960/10000)
# Processing prefix group: 99996x (9970/10000)
# Processing prefix group: 99997x (9980/10000)
# Processing prefix group: 99998x (9990/10000)
# Processing prefix group: 99999x (10000/10000)
# Systematic fetch complete
# Done
